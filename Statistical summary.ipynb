# %%
from __future__ import print_function
import pyspark
from pyspark.sql import SparkSession
from pyspark.mllib.stat import Statistics
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Load the data
df1 = spark.read.format("csv").load("dbfs:/FileStore/shared_uploads/praneethsanthosh555@gmail.com/winequality_red-3.csv",header=True)
df1.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+----------------+-----------+--------------+---------+-------------------+--------------------+-------+----+---------+-------+-------+
# fixed acidity|volatile acidity|citric acid|residual sugar|chlorides|free sulfur dioxide|total sulfur dioxide|density|  pH|sulphates|alcohol|quality|
# +-------------+----------------+-----------+--------------+---------+-------------------+--------------------+-------+----+---------+-------+-------+
#           7.4|             0.7|        0.0|           1.9|    0.076|               11.0|                34.0| 0.9978|3.51|     0.56|    9.4|      5|
#           7.8|            0.88|        0.0|           2.6|    0.098|               25.0|                67.0| 0.9968| 3.2|     0.68|    9.8|      5|
#           7.8|            0.76|       0.04|           2.3|    0.092|               15.0|                54.0|  0.997|3.26|     0.65|    9.8|      5|
#          11.2|            0.28|       0.56|           1.9|    0.075|               17.0|                60.0|  0.998|3.16|     0.58|    9.8|      6|
#           7.4|             0.7|        0.0|           1.9|    0.076|               11.0|                34.0| 0.9978|3.51|     0.56|    9.4|      5|
# +-------------+----------------+-----------+--------------+---------+-------------------+--------------------+-------+----+---------+-------+-------+
# only showing top 5 rows
#
# </div>

# %%
#Drop the nan values if it is in the data
data_drop_miss=df1.dropna(how="any")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Drop the label column
features=data_drop_miss.drop("quality")
features.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+----------------+-----------+--------------+---------+-------------------+--------------------+-------+----+---------+-------+
# fixed acidity|volatile acidity|citric acid|residual sugar|chlorides|free sulfur dioxide|total sulfur dioxide|density|  pH|sulphates|alcohol|
# +-------------+----------------+-----------+--------------+---------+-------------------+--------------------+-------+----+---------+-------+
#           7.4|             0.7|        0.0|           1.9|    0.076|               11.0|                34.0| 0.9978|3.51|     0.56|    9.4|
#           7.8|            0.88|        0.0|           2.6|    0.098|               25.0|                67.0| 0.9968| 3.2|     0.68|    9.8|
#           7.8|            0.76|       0.04|           2.3|    0.092|               15.0|                54.0|  0.997|3.26|     0.65|    9.8|
#          11.2|            0.28|       0.56|           1.9|    0.075|               17.0|                60.0|  0.998|3.16|     0.58|    9.8|
#           7.4|             0.7|        0.0|           1.9|    0.076|               11.0|                34.0| 0.9978|3.51|     0.56|    9.4|
# +-------------+----------------+-----------+--------------+---------+-------------------+--------------------+-------+----+---------+-------+
# only showing top 5 rows
#
# </div>

# %%
feature_rdd=features.rdd.map(lambda row: row[0:])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import numpy as np
summary=Statistics.colStats(feature_rdd)
print('Mean: %s' % summary.mean()) #a dense vector containing the mean value of each colunn
print('\nVariance: %s' % summary.variance()) #Column -wise variance
print('\nNumNonzeros: %s' % summary.numNonzeros()) #return a number of zero values in the data
print('\nNorm1: %s' % summary.normL1()) #return a norml1 summary
print('\nMax values: %s' % summary.max()) #return a maximum values
print('\nMin: %s' % summary.min())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Mean: [ 8.31963727  0.52782051  0.27097561  2.5388055   0.08746654 15.87492183
#  46.46779237  0.99674668  3.3111132   0.65814884 10.42298311]
#
# Variance: [3.03141639e+00 3.20623777e-02 3.79474831e-02 1.98789713e+00
#  2.21514265e-03 1.09414884e+02 1.08210237e+03 3.56202945e-06
#  2.38351805e-02 2.87326161e-02 1.13564740e+00]
#
# NumNonzeros: [1599. 1599. 1467. 1599. 1599. 1599. 1599. 1599. 1599. 1599. 1599.]
#
# Norm1: [13303.1       843.985     433.29     4059.55      139.859   25384.
#  74302.       1593.79794  5294.47     1052.38    16666.35   ]
#
# Max values: [ 15.9       1.58      1.       15.5       0.611    72.      289.
#    1.00369   4.01      2.       14.9    ]
#
# Min: [4.6     0.12    0.      0.9     0.012   1.      6.      0.99007 2.74
#  0.33    8.4    ]
# </div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
